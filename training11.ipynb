# %% [markdown]
# <a href="https://colab.research.google.com/github/krithika005/pythoncodes/blob/main/training11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.sample(10)
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 3595 2019-03-07 08:19:19 2019-03-07 08:41:55           1      1.90  14.50
# 1102 2019-03-09 22:34:01 2019-03-09 22:43:02           1      1.79   8.50
# 5917 2019-03-01 00:30:59 2019-03-01 00:37:39           2      1.35   7.00
# 3871 2019-03-07 09:10:21 2019-03-07 09:12:50           1      0.44   4.00
# 3503 2019-03-14 05:21:42 2019-03-14 05:49:13           1     17.85  52.00
# 5006 2019-03-10 04:11:28 2019-03-10 04:17:21           1      0.93   6.00
# 2037 2019-03-25 13:17:36 2019-03-25 13:26:21           1      1.89   8.50
# 2393 2019-03-14 19:16:28 2019-03-14 19:17:55           1      0.26   3.00
# 5458 2019-03-30 20:59:25 2019-03-30 21:46:52           1     24.48  63.53
# 2450 2019-03-20 00:55:55 2019-03-20 01:09:46           5      2.44  11.00
#
#         tip  tolls  total   color      payment                pickup_zone  \
# 3595   3.55   0.00  21.35  yellow  credit card      Upper West Side South
# ...

# %%
df.head(12)
# Out:
#                 pickup             dropoff  passengers  distance  fare   tip  \
# 0  2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1  2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2  2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3  2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4  2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5  2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6  2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7  2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8  2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9  2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
# 10 2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.00
# ...

# %%
df.tail(11)
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.00
# 6423 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.00
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.50
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.50
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total  color      payment               pickup_zone  \
# ...

# %%
df.sample(10)
df.head(6)
df.tail(5)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6428  1.06    0.0   6.36  green  credit card    East Harlem North
# 6429  0.00    0.0  58.80  green  credit card              Jamaica
# 6430  0.00    0.0  17.30  green         cash  Crown Heights North
# 6431  0.00    0.0   6.80  green  credit card        East New York
# 6432  3.36    0.0  20.16  green  credit card          Boerum Hill
#
#                           dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df['color']
# Out:
# 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object

# %%
df['color'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.isnull().sum()/6433
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.006840
# pickup_zone        0.004042
# dropoff_zone       0.006995
# pickup_borough     0.004042
# dropoff_borough    0.006995
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
missing data handling
1. Imputation (fill in the blanks)
    1. statical measures
    2. parameter domain
2. delete data
  rows
  columns

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.drop('pickup_zone',axis=1)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.drop('pickup_zone',axis=1,inplace=True)

# %%
df.drop(['pickup','color','payment','total'],axis=1)
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0
# 2    2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0
# 3    2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0
# ...                  ...         ...       ...   ...   ...    ...
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0
# 6430 2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0
#
#                           dropoff_zone pickup_borough dropoff_borough
# 0                  UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop([2,3,6430,6432],axis=0,)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop([2,3,6430,6432],axis=0)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop([2,3,6430,6432],axis=0,inplace=True)

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index()
# Out:
#       index              pickup             dropoff  passengers  distance  \
# 0         0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60
# 1         1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79
# 2         4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16
# 3         5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49
# 4         6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65
# ...     ...                 ...                 ...         ...       ...
# 6424   6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71
# 6425   6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07
# 6426   6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75
# 6427   6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74
# 6428   6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12
#
#       fare   tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index(drop=True)# its mandatory to apply reset-index after deleting rows from dataframes
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 3    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 4    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6424 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.5
# 6425 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0
# 6426 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6427 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6428 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df[df['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 3    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 4    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 5444 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5445 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5446 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5447 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5448 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment                  dropoff_zone  \
# ...

# %%
df['color']=='yellow'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6424    False
# 6425    False
# 6426    False
# 6427    False
# 6428    False
# Name: color, Length: 6429, dtype: bool

# %%
total15=df[df['total']>15]
total15
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 4    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.00
# 6    2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.00
# 8    2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.00
# 13   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.50
# 14   2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.00
# ...                  ...                 ...         ...       ...    ...
# 6420 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.00
# 6421 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6423 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6425 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6427 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
#
#       tip  tolls  total   color      payment  \
# ...

# %%
type(total15)
# Out:
# pandas.core.frame.DataFrame
