# %% [markdown]
# <a href="https://colab.research.google.com/github/krithika005/pythoncodes/blob/main/training17_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

# %%
df['smoker']=lb.fit_transform(df['smoker'])
df['sex']=lb.fit_transform(df['sex'])
df['time']=lb.fit_transform(df['time'])
df['day']=lb.fit_transform(df['day'])

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex             int64
# smoker          int64
# day             int64
# time            int64
# size            int64
# dtype: object

# %%
df.head(2)
# Out:
#    total_bill   tip  sex  smoker  day  time  size
# 0       16.99  1.01    0       0    2     0     2
# 1       10.34  1.66    1       0    2     0     3

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Purples')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Blues')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Reds')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),annot=True,cmap='Greens')
plt.show()

# %%
import matplotlib.pyplot as plt
sns.heatmap(np.abs(df.corr()),cmap='Greens')
plt.show()

# %%
sns.heatmap(np.abs(df.corr())>0.5,cmap='Greens')
plt.show()

# %%
sns.heatmap(np.abs(df.corr())>0.7,cmap='Greens')
plt.show()

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
df.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443    0.381148    1.741803    0.278689
# std      8.902412    1.383638    0.479967    0.486667    0.926815    0.449276
# min      3.070000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     13.347500    2.000000    0.000000    0.000000    1.000000    0.000000
# 50%     17.795000    2.900000    1.000000    0.000000    2.000000    0.000000
# 75%     24.127500    3.562500    1.000000    1.000000    3.000000    1.000000
# max     50.810000   10.000000    1.000000    1.000000    3.000000    1.000000
#
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
sc_array=sc.fit_transform(df)

# %%
sc_array.shape
# Out:
# (244, 7)

# %%
sc_df=pd.DataFrame(sc_array,columns=df.columns)
sc_df.head(3)
# Out:
#    total_bill       tip       sex    smoker       day      time      size
# 0   -0.314711 -1.439947 -1.343353 -0.784789  0.279158 -0.621582 -0.600193
# 1   -1.063235 -0.969205  0.744406 -0.784789  0.279158 -0.621582  0.453383
# 2    0.137780  0.363356  0.744406 -0.784789  0.279158 -0.621582  0.453383

# %%
df.describe()
# Out:
#        total_bill         tip         sex      smoker         day        time  \
# count  244.000000  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    0.643443    0.381148    1.741803    0.278689
# std      8.902412    1.383638    0.479967    0.486667    0.926815    0.449276
# min      3.070000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     13.347500    2.000000    0.000000    0.000000    1.000000    0.000000
# 50%     17.795000    2.900000    1.000000    0.000000    2.000000    0.000000
# 75%     24.127500    3.562500    1.000000    1.000000    3.000000    1.000000
# max     50.810000   10.000000    1.000000    1.000000    3.000000    1.000000
#
#              size
# count  244.000000
# mean     2.569672
# std      0.951100
# min      1.000000
# 25%      2.000000
# 50%      2.000000
# 75%      3.000000
# max      6.000000

# %%
from sklearn.preprocessing import MinMaxScaler
mx_scaler=MinMaxScaler()

# %%
mx_array=mx_scaler.fit_transform(df)

# %%
type(mx_array)
# Out:
# numpy.ndarray

# %%
mx_array.shape
# Out:
# (244, 7)

# %%
mx_array=mx_scaler.fit_transform(df)

# %%
df
# Out:
#      total_bill   tip  sex  smoker  day  time  size
# 0         16.99  1.01    0       0    2     0     2
# 1         10.34  1.66    1       0    2     0     3
# 2         21.01  3.50    1       0    2     0     3
# 3         23.68  3.31    1       0    2     0     2
# 4         24.59  3.61    0       0    2     0     4
# ..          ...   ...  ...     ...  ...   ...   ...
# 239       29.03  5.92    1       0    1     0     3
# 240       27.18  2.00    0       1    1     0     2
# 241       22.67  2.00    1       1    1     0     2
# 242       17.82  1.75    1       0    1     0     2
# 243       18.78  3.00    0       0    3     0     2
#
# [244 rows x 7 columns]

# %%
mx_df=pd.DataFrame(mx_array,columns=df.columns)
mx_df.head(8)
# Out:
#    total_bill       tip  sex  smoker       day  time  size
# 0    0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1    0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2    0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3    0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4    0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# 5    0.465438  0.412222  1.0     0.0  0.666667   0.0   0.6
# 6    0.119397  0.111111  1.0     0.0  0.666667   0.0   0.2
# 7    0.498743  0.235556  1.0     0.0  0.666667   0.0   0.6

# %%
mx_df
# Out:
#      total_bill       tip  sex  smoker       day  time  size
# 0      0.291579  0.001111  0.0     0.0  0.666667   0.0   0.2
# 1      0.152283  0.073333  1.0     0.0  0.666667   0.0   0.4
# 2      0.375786  0.277778  1.0     0.0  0.666667   0.0   0.4
# 3      0.431713  0.256667  1.0     0.0  0.666667   0.0   0.2
# 4      0.450775  0.290000  0.0     0.0  0.666667   0.0   0.6
# ..          ...       ...  ...     ...       ...   ...   ...
# 239    0.543779  0.546667  1.0     0.0  0.333333   0.0   0.4
# 240    0.505027  0.111111  0.0     1.0  0.333333   0.0   0.2
# 241    0.410557  0.111111  1.0     1.0  0.333333   0.0   0.2
# 242    0.308965  0.083333  1.0     0.0  0.333333   0.0   0.2
# 243    0.329074  0.222222  0.0     0.0  1.000000   0.0   0.2
#
# [244 rows x 7 columns]

# %%
scale_df=pd.DataFrame(sc_array,columns=df.columns)
scale_df.head(8)
# Out:
#    total_bill       tip       sex    smoker       day      time      size
# 0   -0.314711 -1.439947 -1.343353 -0.784789  0.279158 -0.621582 -0.600193
# 1   -1.063235 -0.969205  0.744406 -0.784789  0.279158 -0.621582  0.453383
# 2    0.137780  0.363356  0.744406 -0.784789  0.279158 -0.621582  0.453383
# 3    0.438315  0.225754  0.744406 -0.784789  0.279158 -0.621582 -0.600193
# 4    0.540745  0.443020 -1.343353 -0.784789  0.279158 -0.621582  1.506958
# 5    0.619537  1.239659  0.744406 -0.784789  0.279158 -0.621582  1.506958
# 6   -1.239955 -0.722971  0.744406 -0.784789  0.279158 -0.621582 -0.600193
# 7    0.798507  0.088153  0.744406 -0.784789  0.279158 -0.621582  1.506958

# %%
import statsmodels.api as sm
sm.qqplot(df['total_bill'],line='45')
plt.show()

# %%
import statsmodels.api as sm
sm.qqplot(df['tip'],line='45')
plt.show()

# %%
sns.regplot(x='total_bill',y='tip',data=df,ci=None,line_kws={'color':'yellow'},scatter_kws={'color':'purple'})
plt.show()

# %%
sns.regplot(x='smoker',y='tip',data=df,ci=None,line_kws={'color':'blue'},scatter_kws={'color':'red'})
plt.show()
