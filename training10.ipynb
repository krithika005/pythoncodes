# %% [markdown]
# <a href="https://colab.research.google.com/github/krithika005/pythoncodes/blob/main/training10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.load_dataset('diamonds')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].unique()
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
4577+1822
# Out:
# 6399

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.iloc[2]
# Out:
# pickup             2019-03-27 17:53:01
# dropoff            2019-03-27 18:00:25
# passengers                           1
# distance                          1.37
# fare                               7.5
# tip                               2.36
# tolls                              0.0
# total                            14.16
# color                           yellow
# payment                    credit card
# pickup_zone              Alphabet City
# dropoff_zone              West Village
# pickup_borough               Manhattan
# dropoff_borough              Manhattan
# Name: 2, dtype: object

# %%
df.iloc[2:10,3:10]
# Out:
#    distance  fare   tip  tolls  total   color      payment
# 2      1.37   7.5  2.36    0.0  14.16  yellow  credit card
# 3      7.70  27.0  6.15    0.0  36.95  yellow  credit card
# 4      2.16   9.0  1.10    0.0  13.40  yellow  credit card
# 5      0.49   7.5  2.16    0.0  12.96  yellow  credit card
# 6      3.65  13.0  2.00    0.0  18.80  yellow  credit card
# 7      1.40   8.5  0.00    0.0  11.80  yellow          NaN
# 8      3.63  15.0  1.00    0.0  19.30  yellow  credit card
# 9      1.52   8.0  1.00    0.0  13.30  yellow  credit card

# %%
df.loc[2:10,['distance','fare','total','payment']]
# Out:
#     distance  fare  total      payment
# 2       1.37   7.5  14.16  credit card
# 3       7.70  27.0  36.95  credit card
# 4       2.16   9.0  13.40  credit card
# 5       0.49   7.5  12.96  credit card
# 6       3.65  13.0  18.80  credit card
# 7       1.40   8.5  11.80          NaN
# 8       3.63  15.0  19.30  credit card
# 9       1.52   8.0  13.30  credit card
# 10      3.90  17.0  17.80         cash

# %%
a=np.random.randint(10,50,25)
a
# Out:
# array([17, 45, 30, 22, 31, 38, 34, 10, 13, 17, 23, 26, 31, 35, 43, 36, 40,
#        49, 38, 42, 10, 49, 41, 14, 34])

# %%
a[a>30]
# Out:
# array([45, 31, 38, 34, 31, 35, 43, 36, 40, 49, 38, 42, 49, 41, 34])

# %%
df[df['payment']=='cash']
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.0
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.0
# 13   2019-03-19 07:55:25 2019-03-19 08:09:17           1      1.75  10.5  0.0
# 14   2019-03-27 12:13:34 2019-03-27 12:25:48           0      2.90  11.5  0.0
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.0
# ...                  ...                 ...         ...       ...   ...  ...
# 6420 2019-03-16 15:39:23 2019-03-16 15:46:18           2      1.20   7.0  0.0
# 6422 2019-03-22 20:17:35 2019-03-22 20:36:07           1      4.02  16.0  0.0
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.0  0.0
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.0  0.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0  0.0
#
# ...

# %%
df[df['total']>=10]
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.00
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.50
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.00
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.00
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.50
# ...                  ...                 ...         ...       ...    ...
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total   color      payment                pickup_zone  \
# ...

# %%
import numpy as np

# %%
a=pd.Series(['India',5,2,4,8.6,9])
a
# Out:
# 0    India
# 1        5
# 2        2
# 3        4
# 4      8.6
# 5        9
# dtype: object

# %%
#80     preprocessing  10 training    10 fine tunning
